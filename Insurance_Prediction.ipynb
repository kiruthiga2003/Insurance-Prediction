# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7a89b44c-9c6c-4889-9726-9e11303dcd20" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7a89b44c-9c6c-4889-9726-9e11303dcd20">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('/content/police.csv')

# %%
df.head()
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
df.tail()
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 91736        29.0       White                        Speeding
# 91737        33.0       White  Equipment/Inspection Violation
# 91738        23.0       White         Other Traffic Violation
# 91739        22.0       White                        Speeding
# 91740        56.0    Hispanic                        Speeding
#
#               violation  search_conducted search_type stop_outcome  \
# 91736          Speeding             False         NaN      Warning
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   county_name         0 non-null      float64
#  3   driver_gender       86406 non-null  object
#  4   driver_age_raw      86414 non-null  float64
#  5   driver_age          86120 non-null  float64
#  6   driver_race         86408 non-null  object
#  7   violation_raw       86408 non-null  object
#  8   violation           86408 non-null  object
#  9   search_conducted    91741 non-null  bool
#  10  search_type         3196 non-null   object
#  11  stop_outcome        86408 non-null  object
#  12  is_arrested         86408 non-null  object
#  13  stop_duration       86408 non-null  object
#  14  drugs_related_stop  91741 non-null  bool
# ...

# %%
df.drop(['county_name'],axis = 1, inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   driver_gender       86406 non-null  object
#  3   driver_age_raw      86414 non-null  float64
#  4   driver_age          86120 non-null  float64
#  5   driver_race         86408 non-null  object
#  6   violation_raw       86408 non-null  object
#  7   violation           86408 non-null  object
#  8   search_conducted    91741 non-null  bool
#  9   search_type         3196 non-null   object
#  10  stop_outcome        86408 non-null  object
#  11  is_arrested         86408 non-null  object
#  12  stop_duration       86408 non-null  object
#  13  drugs_related_stop  91741 non-null  bool
# dtypes: bool(2), float64(2), object(10)
# memory usage: 8.6+ MB

# %%
df['stop_date'] = pd.to_datetime(df['stop_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  datetime64[ns]
#  1   stop_time           91741 non-null  object
#  2   driver_gender       86406 non-null  object
#  3   driver_age_raw      86414 non-null  float64
#  4   driver_age          86120 non-null  float64
#  5   driver_race         86408 non-null  object
#  6   violation_raw       86408 non-null  object
#  7   violation           86408 non-null  object
#  8   search_conducted    91741 non-null  bool
#  9   search_type         3196 non-null   object
#  10  stop_outcome        86408 non-null  object
#  11  is_arrested         86408 non-null  object
#  12  stop_duration       86408 non-null  object
#  13  drugs_related_stop  91741 non-null  bool
# dtypes: bool(2), datetime64[ns](1), float64(2), object(9)
# ...

# %%
df.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
df['driver_gender'].fillna(df['driver_gender'].mode()[0], inplace=True)

# %%
df.get
# Out:
# <bound method NDFrame.get of        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0     2005-01-02     01:55             M          1985.0        20.0
# 1     2005-01-18     08:15             M          1965.0        40.0
# 2     2005-01-23     23:15             M          1972.0        33.0
# 3     2005-02-20     17:15             M          1986.0        19.0
# 4     2005-03-14     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 91736 2015-12-31     20:27             M          1986.0        29.0
# 91737 2015-12-31     20:35             F          1982.0        33.0
# 91738 2015-12-31     20:45             M          1992.0        23.0
# 91739 2015-12-31     21:42             M          1993.0        22.0
# 91740 2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
df['driver_gender'].fillna(df['driver_gender'].mode()[0], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  datetime64[ns]
#  1   stop_time           91741 non-null  object
#  2   driver_gender       91741 non-null  object
#  3   driver_age_raw      86414 non-null  float64
#  4   driver_age          86120 non-null  float64
#  5   driver_race         86408 non-null  object
#  6   violation_raw       86408 non-null  object
#  7   violation           86408 non-null  object
#  8   search_conducted    91741 non-null  bool
#  9   search_type         3196 non-null   object
#  10  stop_outcome        86408 non-null  object
#  11  is_arrested         86408 non-null  object
#  12  stop_duration       86408 non-null  object
#  13  drugs_related_stop  91741 non-null  bool
# dtypes: bool(2), datetime64[ns](1), float64(2), object(9)
# ...

# %%
df['driver_age'].fillna(df['driver_age'].mean(), inplace=True)

# %%
df['search_type'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 91736    NaN
# 91737    NaN
# 91738    NaN
# 91739    NaN
# 91740    NaN
# Name: search_type, Length: 91741, dtype: object>

# %%
df.loc[:5,['driver_age','violation']]
# Out:
#    driver_age  violation
# 0        20.0   Speeding
# 1        40.0   Speeding
# 2        33.0   Speeding
# 3        19.0      Other
# 4        21.0   Speeding
# 5        23.0  Equipment

# %%
df.iloc[:5,:5]
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age
# 0 2005-01-02     01:55             M          1985.0        20.0
# 1 2005-01-18     08:15             M          1965.0        40.0
# 2 2005-01-23     23:15             M          1972.0        33.0
# 3 2005-02-20     17:15             M          1986.0        19.0
# 4 2005-03-14     10:00             F          1984.0        21.0

# %%
df.query('45<driver_age<50').head(8)
# Out:
#      stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 19  2005-07-24     20:10             F          1958.0        47.0
# 30  2005-09-26     12:09             M          1959.0        46.0
# 46  2005-10-01     08:40             M          1959.0        46.0
# 48  2005-10-01     09:20             M          1957.0        48.0
# 57  2005-10-01     18:10             M          1958.0        47.0
# 77  2005-10-02     08:40             M          1957.0        48.0
# 84  2005-10-02     12:05             F          1959.0        46.0
# 118 2005-10-04     01:20             M          1956.0        49.0
#
#     driver_race                   violation_raw         violation  \
# 19        White                        Speeding          Speeding
# 30        Black         Other Traffic Violation  Moving violation
# 46        White  Equipment/Inspection Violation         Equipment
# 48        White                        Speeding          Speeding
# ...

# %%
df.query('driver_age==25 and driver_gender=="F"')
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 189   2005-10-06     16:32             F          1980.0        25.0
# 196   2005-10-06     23:30             F          1980.0        25.0
# 235   2005-10-08     10:25             F          1980.0        25.0
# 436   2005-10-18     07:40             F          1980.0        25.0
# 437   2005-10-18     09:05             F          1980.0        25.0
# ...          ...       ...           ...             ...         ...
# 91346 2015-12-11     00:12             F          1990.0        25.0
# 91428 2015-12-14     13:56             F          1990.0        25.0
# 91456 2015-12-16     02:17             F          1990.0        25.0
# 91630 2015-12-27     02:54             F          1990.0        25.0
# 91699 2015-12-30     08:35             F          1990.0        25.0
#
#       driver_race                   violation_raw         violation  \
# 189         White                        Speeding          Speeding
# ...

# %%
newdf = pd.get_dummies(df.driver_race,prefix="driver_race_").iloc[:,0:]

# %%
import numpy as np

# %%
num_df = df.select_dtypes(include=[np.number])
num_df
# Out:
#        driver_age_raw  driver_age
# 0              1985.0        20.0
# 1              1965.0        40.0
# 2              1972.0        33.0
# 3              1986.0        19.0
# 4              1984.0        21.0
# ...               ...         ...
# 91736          1986.0        29.0
# 91737          1982.0        33.0
# 91738          1992.0        23.0
# 91739          1993.0        22.0
# 91740          1959.0        56.0
#
# [91741 rows x 2 columns]
